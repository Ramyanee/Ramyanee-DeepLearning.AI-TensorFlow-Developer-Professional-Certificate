# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramyanee/Ramyanee-DeepLearning.AI-TensorFlow-Developer-Professional-Certificate/blob/main/course1/horse%26man.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls gdrive/MyDrive
# Out:
# '0. Applied Gate Notes'  'Getting started.pdf'	 resume_ramyanee.pdf
# 'Colab Notebooks'	  ramyanee_resume.pdf

# %%
# !unzip gdrive/MyDrive/horse-or-human.zip
# Out:
# Archive:  gdrive/MyDrive/horse-or-human.zip
#    creating: horse-or-human/train/
#    creating: horse-or-human/train/horses/
#   inflating: horse-or-human/train/horses/horse01-0.png
#   inflating: horse-or-human/train/horses/horse01-1.png
#   inflating: horse-or-human/train/horses/horse01-2.png
#   inflating: horse-or-human/train/horses/horse01-3.png
#   inflating: horse-or-human/train/horses/horse01-4.png
#   inflating: horse-or-human/train/horses/horse01-5.png
#   inflating: horse-or-human/train/horses/horse01-6.png
#   inflating: horse-or-human/train/horses/horse01-7.png
#   inflating: horse-or-human/train/horses/horse01-8.png
#   inflating: horse-or-human/train/horses/horse01-9.png
#   inflating: horse-or-human/train/horses/horse02-0.png
#   inflating: horse-or-human/train/horses/horse02-1.png
#   inflating: horse-or-human/train/horses/horse02-2.png
#   inflating: horse-or-human/train/horses/horse02-3.png
#   inflating: horse-or-human/train/horses/horse02-4.png
# ...

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'horse-or-human/train',
    target_size = (300,300),
    batch_size = 128,
    class_mode = 'binary'
)


validation_generator = train_datagen.flow_from_directory(
    'horse-or-human/validation',
    target_size = (300,300),
    batch_size = 128,
    class_mode = 'binary'
)
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
def create_model():
  model = tf.keras.models.Sequential([
                                      tf.keras.layers.Conv2D(16,(3,3), activation='relu', input_shape = (300,300,3)),
                                      tf.keras.layers.MaxPooling2D(2,2),
                                      tf.keras.layers.Conv2D(32,(3,3), activation='relu'),
                                      tf.keras.layers.MaxPooling2D(2,2),
                                      tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
                                      tf.keras.layers.MaxPooling2D(2,2),
                                      tf.keras.layers.Flatten(),
                                      tf.keras.layers.Dense(512, activation='relu'),
                                      tf.keras.layers.Dense(1, activation='sigmoid')

  ])

  

  return model

# %%
model = create_model()

# %%
model.compile(loss='binary_crossentropy',
                optimizer=RMSprop(lr=0.001),
                metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
history =  model.fit_generator(
    train_generator,
    steps_per_epoch=8,
    epochs=15,
    validation_data = validation_generator,
    validation_steps=8,
    verbose=2
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/15
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 8 batches). You may need to use the repeat() function when building your dataset.
# 8/8 - 40s - loss: 6.7376 - acc: 0.5050 - val_loss: 0.6459 - val_acc: 0.5273
# Epoch 2/15
# 8/8 - 6s - loss: 0.6214 - acc: 0.7559
# Epoch 3/15
# 8/8 - 6s - loss: 0.4600 - acc: 0.8065
# Epoch 4/15
# 8/8 - 6s - loss: 0.4037 - acc: 0.8899
# Epoch 5/15
# 8/8 - 6s - loss: 0.1105 - acc: 0.9629
# Epoch 6/15
# 8/8 - 6s - loss: 0.0602 - acc: 0.9800
# Epoch 7/15
# 8/8 - 6s - loss: 0.0501 - acc: 0.9811
# Epoch 8/15
# ...

# %%
from google.colab import files
from keras.preprocessing import image
uploaded = files.upload()
for fn in uploaded.keys():
  path = '/content/'+fn
  img=image.load_img(path,target_size=(300,300))
  x = image.img_to_array(img)
  x = np.expand_dims(x,axis=0)

  images= np.vstack([x])
  classes= model.predict(images,batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn+' is a human')
  else:
    print(fn+' is a horse')
# Out:
#      <input type="file" id="files-320821ed-1eb5-4514-8ab2-03a9f938b07d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-320821ed-1eb5-4514-8ab2-03a9f938b07d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-02-24 at 10.02.23 AM.jpeg to WhatsApp Image 2021-02-24 at 10.02.23 AM.jpeg
# [1.]
# WhatsApp Image 2021-02-24 at 10.02.23 AM.jpeg is a human
